# %% [markdown]
# ## Reglas de Asociación
#
# ### 1) Descubrimiento de asociaciones
#
# - Búsqueda de patrones frecuentes, asociaciones, correlaciones o estructuras causales entre conjuntos de artículos u objetos (datos) a partir de bases de datos transaccionales, relacionales y conjuntos de datos.
#
#
# - Búsqueda de secuencias o patrones temporales
#
#
# - Aplicaciones:
#     - Análisis de carritos de compra
#     - Diseño de catálogos,...
#     - ¿Qué hay en el carrito? corbatas
#     - ¿Cómo motivar al cliente a comprar los artículos que es probable que le gusten?
#
#
# ### 2) Reglas de asociación
#
# - Objetivo de los algoritmos de extracción de reglas de asociación:
#     - Dada una **base de datos de transacciones**, donde cada transacción es una lista de artículos (comprados por un cliente en una misma visita)
#
#     - Encontrar todas las reglas que corelacionen la presencia de un conjunto de artículos con otro conjunto de artículos.
#
#     - Ejemplo : 89% de la gente que compra neumáticos y accesorios para el automóvil, también requiere servicios.
#
#
# La idea es obtener reglas de tipo:
#
# - Antecedente => Consecuente [soporte, confianza]
# - Compra (x , pañales) => compra(x, cerveza) [0.5% , 60%]
#
#
# - Encontrar todas las reglas X ^ Y => Z con un mínimo de confianza y de soporte
#
# - Soporte (s): La probabilidad de que una transacción cotenga {X ^ Y ^ Z}
#
# - Confianza (c): Probabilidad condicional P( Z | X ^ Y )
#
#
# ### El soporte habitual podría ir entre el 5 y 10 %
#
# Con un **Soporte**:
#
# - Alto => habrá pocas reglas que ocurren con frecuencia (obviedades)
# - Bajo => habrá muchas reglas que ocurren raramente ()
#
#
# Con una **Confianza:**
#
# - Alta => pocas reglas, pero todas **casi ciertas logicamente**
#
# - Baja => muchas reglas, pero muchas de ellas muy **inciertas**
#
# Un ejemplo de **Soporte** sería, dentro de todas las transacciones, el % frecuencia de la familia Corbata
#
# y de **Confianza** sería, dentro del número de transacciones con Corbata, el % de otra Familia (Camisa p.e.)
#
# #### Valores típicos
#
# **Soporte:** 2-10 %
#
# **Confianza** 70-90%
#
# **Lift** hacer caso al lift > 1
#
# ### 3) El algoritmo APRIORI
#
# - Ecuentra las asociaciones más frecuentes
# - Itera sobre la base de datos hasta que las asociaciones obtenidas no tienen el soporte mínimo.
# - Método simple pero robusto
# - Salida intuitiva
#
#
# - Requisitos:
#   + No necesita fijar los atributos de los lados derecho (consecuente) e izquierdo (antecedente) de las reglas, pues se generan de manera automática
#   + Existen variedades para tratar todo tipo de datos
#   + Especificar mínimo soporte
#   + Especificar máximo número de reglas.
#
# El algortimo busca iterativamente conjuntos frecuentes con cardinalidad 1 hasta k (k-conjunto), y después **usa los conjuntos frecuentes para crear reglas de asociación.**
#
# En el paso clave del descubrimiento de **conjuntos frecuentes**, se basa en el principio "a priori"
#
# - Cualquier subconjunto de un conjunto de artículos frecuente debe ser frecuente
#
#   Ejemplo: si {A B} es un conjunto frecuente, entonces tanto {A} como {B} deberían ser frecuentes
#
# Y por el contrario si existe algún conjunto "infrecuente", entonces no hay necesidad de generar sus superconjuntos

# %%
import pandas as pd
import pyodbc

#pyodbc
server = 'tcp:190.27.1.13\BI'
database = 'dbHighLife'
username = 'srodriguez'
password = 'Zmadgfv1'

cnxn = pyodbc.connect('DRIVER={ODBC Driver 13 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()


consulta = '''  select Familias from Apriori_HL where Familias <> ''  '''

resultado = []


registros = cursor.execute(consulta).fetchall()

# %%
for x in registros:
    resultado.append(x.Familias.split(","))

# %%
resultado
# Out:
# [['CAMISA V'],
#  ['PANTALON V'],
#  ['CAMISA V'],
#  ['TRAJE'],
#  ['MONO'],
#  ['CAMISA V'],
#  ['BLAZER', 'SACO SPORT'],
#  ['SACO SPORT'],
#  ['CALZADO', 'CAMISA V', 'PANUELO', 'TRAJE'],
#  ['PANTALON V'],
#  ['CORBATA'],
#  ['PULSERA'],
#  ['SACO SPORT'],
#  ['CALCETIN'],
#  ['CALCETIN', 'CORBATA'],
#  ['CALCETIN', 'CAMISA V', 'CORBATA', 'TRAJE TRIO'],
#  ['ABRIGO', 'CHAMARRA'],
#  ['MONO'],
#  ['PANTALON V', 'TRAJE'],
#  ['PANTALON S'],
#  ['MONO', 'TRAJE TRIO'],
#  ['CAMISA V'],
#  ['CHALECO'],
#  ['CORBATA'],
#  ['MONO'],
#  ['CAMISA V'],
#  ['TRAJE'],
#  ['TRAJE TRIO'],
#  ['PANTALON S'],
#  ['MANCUERNIL', 'TRAJE'],
#  ['CORBATA'],
#  ['BLAZER', 'PANTALON V', 'SACO SPORT'],
#  ['CORBATA'],
#  ['CALCETIN', 'CINTURON', 'CORBATA'],
#  ['MONO', 'TRAJE'],
#  ['CAMISA SP', 'CAMISA V'],
#  ['CORBATA'],
#  ['CAMISA V', 'SACO SPORT'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['CHALECO'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['CHAMARRA'],
#  ['PANUELO'],
#  ['TRAJE'],
#  ['PANTS'],
#  ['ABRIGO'],
#  ['CALCETIN',
#   'CALZADO',
#   'CAMISA V',
#   'CINTURON',
#   'FAJAYMONO',
#   'MANCUERNIL',
#   'PANUELO',
#   'SMOKING'],
#  ['ABRIGO',
#   'CAMISA SP',
#   'CAMISA V',
#   'PANTALON S',
#   'PANTALON V',
#   'PANUELO',
#   'SACO SPORT'],
#  ['PANUELO'],
#  ['CORBATA', 'TRAJE'],
#  ['MONO'],
#  ['TRAJE', 'TRAJE TRIO'],
#  ['PANTALON V'],
#  ['MONO'],
#  ['PLAYERA'],
#  ['SACO SPORT'],
#  ['ABRIGO'],
#  ['TRAJE'],
#  ['SACO SPORT'],
#  ['BRAZALETE'],
#  ['TRAJE'],
#  ['PANTALON V'],
#  ['CORBATA', 'TRAJE TRIO'],
#  ['CAMISA V'],
#  ['CHAMARRA'],
#  ['CAMISA V', 'CORBATA', 'TRAJE TRIO'],
#  ['CAMISA V'],
#  ['SACO SPORT'],
#  ['CHAMARRA'],
#  ['CORBATA'],
#  ['FISTOL', 'MONO', 'TRAJE TRIO'],
#  ['TRAJE'],
#  ['CAMISA V', 'PANTALON V', 'SACO SPORT'],
#  ['CAMISA V'],
#  ['TRAJE'],
#  ['PLAYPOLO'],
#  ['TIRANTES'],
#  ['SACO SPORT'],
#  ['SACO SPORT'],
#  ['SACO SPORT'],
#  ['SACO SPORT'],
#  ['PANTALON V', 'SACO SPORT'],
#  ['CALCETIN', 'CAMISA V', 'TRAJE'],
#  ['CAMISA V'],
#  ['CAMISA SP', 'PANTALON S', 'PANTALON V'],
#  ['SACO SPORT'],
#  ['CAMISA SP', 'CAMISA V', 'PANTALON S', 'PANTALON V', 'SACO SPORT'],
#  ['PANTALON S'],
#  ['CAMISA SP', 'PANUELO'],
#  ['CAMISA SP', 'CAMISA V'],
#  ['BRAZALETE', 'SACO SPORT'],
#  ['CAMISA V'],
#  ['TRAJE'],
#  ['PANUELO'],
#  ['SACO SPORT'],
#  ['TRAJE'],
#  ['SMOKING'],
#  ['TRAJE'],
#  ['PANUELO'],
#  ['TRAJE'],
#  ['PANTALON V'],
#  ['PANUELO'],
#  ['CALCETIN', 'TRAJE'],
#  ['CAMISA SP', 'PANUELO'],
#  ['PANTALON S', 'PLAYPOLO'],
#  ['CALZADO'],
#  ['CALCETIN', 'CHALECO V'],
#  ['SACO SPORT'],
#  ['CAMISA V', 'CHALECO'],
#  ['TRAJE'],
#  ['PANTALON V', 'SACO SPORT', 'TRAJE'],
#  ['CHALECO', 'CHALECO V'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['CORBATA'],
#  ['CHALECO'],
#  ['SACO SPORT'],
#  ['CAMISA V'],
#  ['SACO SPORT'],
#  ['CHALECO'],
#  ['CAMISA V', 'CHALECO'],
#  ['PANUELO', 'PLAYERA', 'SACO SPORT'],
#  ['PANUELO'],
#  ['CAMISA V'],
#  ['PANTALON S'],
#  ['CORBATA'],
#  ['CORBATA'],
#  ['JEANS'],
#  ['PANUELO'],
#  ['CAMISA V', 'PANTALON S', 'SACO SPORT', 'TRAJE'],
#  ['CAMISA V', 'TRAJE'],
#  ['MONO'],
#  ['CAMISA SP'],
#  ['CALCETIN'],
#  ['CALCETIN', 'PANUELO', 'ROPA INT'],
#  ['SACO SPORT'],
#  ['BLAZER', 'PLAYERA'],
#  ['CORBATA'],
#  ['CHALECO'],
#  ['CHAMARRA'],
#  ['CAMISA SP', 'TRAJE'],
#  ['CAMISA V', 'PANTALON V'],
#  ['CALCETIN', 'PANTALON V', 'PANTS', 'SACO SPORT'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['CHAMARRA', 'CINTURON'],
#  ['PANUELO'],
#  ['CAMISA SP', 'CAMISA V'],
#  ['CORBATA'],
#  ['TRAJE'],
#  ['CORBATA'],
#  ['SACO SPORT'],
#  ['CORBATA'],
#  ['CAMISA V', 'CORBATA', 'PANUELO', 'TRAJE'],
#  ['PLAYPOLO'],
#  ['CALCETIN'],
#  ['PANTALON V', 'SACO SPORT'],
#  ['CINTURON'],
#  ['PANUELO'],
#  ['CALZADO'],
#  ['PANTALON V'],
#  ['CORBATA'],
#  ['SACO SPORT'],
#  ['CINTURON'],
#  ['TRAJE TRIO'],
#  ['CHALECO V', 'CORBATA', 'PANTALON V', 'SACO SPORT'],
#  ['CAMISA V', 'CINTURON', 'PANTALON S'],
#  ['SUETER'],
#  ['BLAZER', 'CAMISA V'],
#  ['PANTALON V'],
#  ['CINTURON', 'PANTALON S', 'PANTALON V'],
#  ['CHALECO', 'CHALECO V', 'CHAMARRA'],
#  ['CORBATA', 'TRAJE'],
#  ['CHALECO'],
#  ['PANTALON V'],
#  ['PANTALON V'],
#  ['PANUELO'],
#  ['BLAZER'],
#  ['CORBATA', 'PANTALON V', 'SACO SPORT'],
#  ['CAMISA V', 'CHAMARRA', 'MONO', 'PANTALON S', 'TRAJE'],
#  ['CAMISA V', 'TRAJE'],
#  ['CHALECO', 'CHALECO V', 'SACO SPORT'],
#  ['CAMISA V', 'MANCUERNIL', 'PANUELO'],
#  ['CALCETIN', 'CALZADO'],
#  ['CORBATA'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['PANTALON V'],
#  ['MONO'],
#  ['CHAMARRA', 'PANTALON S'],
#  ['PANUELO'],
#  ['MANCUERNIL', 'TRAJE'],
#  ['PANTALON V'],
#  ['CORBATA'],
#  ['CAMISA SP', 'CAMISA V', 'PANTALON V'],
#  ['PLAYERA'],
#  ['CHALECO'],
#  ['CAMISA V', 'PANTALON V'],
#  ['SACO SPORT'],
#  ['BLAZER', 'CAMISA V'],
#  ['CALCETIN'],
#  ['PANTALON V'],
#  ['PLAYERA'],
#  ['CAMISA SP', 'PANTALON S'],
#  ['TRAJE'],
#  ['CAMISA SP'],
#  ['CAMISA V'],
#  ['CAMISA V'],
#  ['CAMISA V'],
#  ['CHALECO', 'PANTALON V'],
#  ['BLAZER'],
#  ['CAMISA V'],
#  ['CALZADO'],
#  ['TRAJE'],
#  ['CAMISA V', 'MONO', 'TRAJE TRIO'],
#  ['CORBATA', 'SACO SPORT'],
#  ['SACO SPORT', 'TRAJE'],
#  ['CHAMARRA', 'CORBATA', 'SACO SPORT'],
#  ['SUETER'],
#  ['CAMISA V', 'SACO SPORT', 'SMOKING'],
#  ['MANCUERNIL'],
#  ['CORBATA'],
#  ['TRAJE TRIO'],
#  ['PANTALON V', 'TRAJE'],
#  ['PLAYERA', 'SACO SPORT'],
#  ['PANTALON V'],
#  ['PANUELO', 'SACO SPD'],
#  ['PANTALON S'],
#  ['TRAJE'],
#  ['PANTALON S'],
#  ['MONEY CLIP'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['TRAJE'],
#  ['CALCETIN', 'CHAMARRA'],
#  ['CALCETIN'],
#  ['CAMISA V'],
#  ['SACO SPORT'],
#  ['CALZADO'],
#  ['CINTURON'],
#  ['ROPA INT'],
#  ['CAMISA V'],
#  ['TRAJE'],
#  ['CAMISA V'],
#  ['PANTALON V'],
#  ['CHAMARRA'],
#  ['CORBATA'],
#  ['CAMISA V'],
#  ['BLAZER'],
#  ['CALCETIN', 'MONO', 'SMOKING'],
#  ['CHAMARRA'],
#  ['CALCETIN', 'SACO SPORT'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['CINTURON'],
#  ['PANTALON S'],
#  ['PANTALON S'],
#  ['CALZADO'],
#  ['CAMISA V', 'PANUELO', 'TRAJE'],
#  ['TRAJE'],
#  ['CAMISA V'],
#  ['BRAZALETE'],
#  ['CAMISA V', 'CORBATA'],
#  ['MONO'],
#  ['CORBATA'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['CORBATA', 'PLAYERA', 'TRAJE'],
#  ['GORRA', 'PANTALON S', 'PLAYPOLO'],
#  ['TRAJE'],
#  ['CAMISA V'],
#  ['CAMISA V', 'TRAJE'],
#  ['SUETER'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['CAMISA V', 'SACO SPORT', 'TRAJE'],
#  ['CALCETIN'],
#  ['TRAJE'],
#  ['PLAYPOLO'],
#  ['CAMISA V'],
#  ['CAMISA V', 'TRAJE'],
#  ['PLAYERA'],
#  ['TRAJE'],
#  ['CAMISA V', 'TRAJE'],
#  ['CALCETIN', 'CORBATA'],
#  ['PANTALON V'],
#  ['TRAJE'],
#  ['CALCETIN', 'CAMISA V', 'CHALECO', 'CINTURON', 'CORBATA'],
#  ['CHALECO', 'MONO', 'TRAJE'],
#  ['CALCETIN', 'SACO SPORT', 'TRAJE'],
#  ['CALZADO', 'MONO', 'SMOKING', 'TIRANTES'],
#  ['PANTALON V'],
#  ['CAMISA V', 'PULSERA'],
#  ['SACO SPORT'],
#  ['CAMISA V', 'PANTALON S', 'PLAYERA'],
#  ['BLAZER', 'CAMISA V', 'CORBATA'],
#  ['CHAMARRA'],
#  ['CAMISA V', 'CORBATA', 'MANCUERNIL', 'TRAJE'],
#  ['CHAMARRA'],
#  ['ROPA INT'],
#  ['CALZADO', 'CAMISA V', 'CINTURON', 'PANTALON V', 'SACO SPORT'],
#  ['CHALECO', 'PANTALON V', 'SACO SPORT', 'TRAJE'],
#  ['PANTALON V', 'PANTS'],
#  ['CAMISA V', 'PANTALON V'],
#  ['PANTALON V'],
#  ['TRAJE'],
#  ['SACO SPORT'],
#  ['SACO SPORT'],
#  ['CAMISA V'],
#  ['TRAJE TRIO'],
#  ['PANTALON V', 'SACO SPORT', 'TRAJE', 'TRAJE TRIO'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['PANUELO', 'TRAJE'],
#  ['TRAJE'],
#  ['PANUELO', 'TRAJE'],
#  ['PANUELO'],
#  ['CALCETIN'],
#  ['TRAJE'],
#  ['CAMISA V', 'TRAJE'],
#  ['TRAJE'],
#  ['MONO'],
#  ['PANTS', 'PLAYERA'],
#  ['CAMISA V', 'TRAJE'],
#  ['TRAJE'],
#  ['SACO SPORT'],
#  ['PIJAMA', 'PLAYERA'],
#  ['TRAJE', 'TRAJE TRIO'],
#  ['PANUELO'],
#  ['PLAYERA'],
#  ['PANTALON S'],
#  ['CAMISA V'],
#  ['CALCETIN', 'JEANS', 'PANTALON S'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['CAMISA SP', 'CAMISA V', 'PANTALON S', 'PANTALON V'],
#  ['SACO SPORT'],
#  ['CALCETIN'],
#  ['SACO SPORT'],
#  ['CAMISA V'],
#  ['SACO SPORT'],
#  ['MONO'],
#  ['CHAMARRA'],
#  ['PLAYERA'],
#  ['PANTALON V'],
#  ['CAMISA V'],
#  ['CAMISA V'],
#  ['TRAJE TRIO'],
#  ['TRAJE'],
#  ['CALCETIN', 'CAMISA V', 'CINTURON'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['SACO SPORT'],
#  ['PANTALON V', 'SACO SPORT'],
#  ['PANTALON V'],
#  ['JEANS'],
#  ['CORBATA', 'TRAJE'],
#  ['CAMISA SP', 'CAMISA V', 'CHAMARRA', 'PLAYERA'],
#  ['CAMISA SP', 'SACO SPORT', 'TRAJE'],
#  ['PANTALON S'],
#  ['PANTALON V'],
#  ['CALZADO'],
#  ['CALZADO', 'CHAMARRA', 'CORBATA', 'PANTALON S', 'PLAYPOLO'],
#  ['PANTALON S', 'PLAYPOLO', 'SUETER'],
#  ['CINTURON'],
#  ['CAMISA V'],
#  ['TRAJE'],
#  ['MANCUERNIL', 'TRAJE'],
#  ['TRAJE', 'TRAJE TRIO'],
#  ['TRAJE TRIO'],
#  ['JEANS', 'PANTALON V', 'SACO SPORT', 'TRAJE'],
#  ['TRAJE'],
#  ['PANTALON S', 'SUETER'],
#  ['CINTURON'],
#  ['CORBATA'],
#  ['CHAMARRA'],
#  ['CALZADO'],
#  ['CAMISA V', 'PANTALON S', 'SACO SPORT', 'TRAJE'],
#  ['CHALECO'],
#  ['CAMISA V'],
#  ['CHALECO'],
#  ['CAMISA SP'],
#  ['CHALECO'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['PLAYERA'],
#  ['CALCETIN', 'CAMISA V', 'CORBATA', 'TRAJE'],
#  ['CALZADO'],
#  ['TRAJE TRIO'],
#  ['CAMISA SP', 'CAMISA V', 'CORBATA', 'TRAJE'],
#  ['CALZADO'],
#  ['PANUELO'],
#  ['CAMISA V', 'TRAJE'],
#  ['CORBATA'],
#  ['CHAMARRA'],
#  ['PANTALON V', 'SACO SPORT'],
#  ['PANTALON V'],
#  ['SACO SPORT'],
#  ['PLAYERA'],
#  ['TRAJE'],
#  ['PANTALON V'],
#  ['CALCETIN', 'SACO SPORT', 'TRAJE'],
#  ['CINTURON'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['PLAYPOLO'],
#  ['CAMISA V'],
#  ['SACO SPORT'],
#  ['CAMISA V', 'CHALECO', 'CORBATA', 'TRAJE'],
#  ['CALZADO', 'PANTALON S'],
#  ['SACO SPORT'],
#  ['PANTALON V'],
#  ['CAMISA V'],
#  ['MANCUERNIL'],
#  ['CAMISA V'],
#  ['CAMISA SP', 'CAMISA V', 'CHALECO', 'TRAJE'],
#  ['TRAJE'],
#  ['CINTURON', 'TRAJE'],
#  ['CHALECO'],
#  ['CHALECO', 'PLAYPOLO'],
#  ['PANTALON V'],
#  ['CALCETIN'],
#  ['SACO SPORT'],
#  ['SACO SPORT', 'TRAJE'],
#  ['CAMISA V', 'CORBATA', 'TRAJE', 'TRAJE TRIO'],
#  ['CHAMARRA'],
#  ['TRAJE'],
#  ['CAMISA V'],
#  ['CAMISA V', 'TRAJE'],
#  ['SMOKING'],
#  ['CHALECO'],
#  ['GORRA', 'PLAYERA', 'PLAYPOLO'],
#  ['TRAJE'],
#  ['CAMISA SP', 'CHAMARRA'],
#  ['TRAJE'],
#  ['BLAZER', 'TRAJE'],
#  ['PANTALON S'],
#  ['PLAYERA'],
#  ['JEANS', 'SACO SPORT'],
#  ['CHALECO'],
#  ['CAMISA V'],
#  ['CAMISA V'],
#  ['CAMISA V'],
#  ['CORBATA', 'TRAJE'],
#  ['TRAJE'],
#  ['CORBATA'],
#  ['CAMISA V', 'PANTALON V'],
#  ['MONO', 'SMOKING'],
#  ['MONO'],
#  ['CAMISA V'],
#  ['BLAZER'],
#  ['MONO'],
#  ['CAMISA V', 'SACO SPORT'],
#  ['CALCETIN', 'PANUELO'],
#  ['CHALECO'],
#  ['CALCETIN', 'CAMISA V'],
#  ['PLAYERA', 'PLAYPOLO'],
#  ['CAMISA V'],
#  ['TRAJE'],
#  ['SACO SPORT'],
#  ['PANTALON V', 'PLAYPOLO'],
#  ['SACO SPORT'],
#  ['CALZADO', 'CAMISA V', 'MONO', 'TRAJE'],
#  ['BLAZER', 'SACO SPORT'],
#  ['PANTALON S'],
#  ['SUETER'],
#  ['CALCETIN', 'CORBATA', 'PLAYERA', 'TRAJE'],
#  ['CAMISA V', 'TRAJE'],
#  ['TRAJE'],
#  ['CORBATA'],
#  ['CHALECO'],
#  ['CORBATA', 'TRAJE'],
#  ['PANTALON V'],
#  ['CHALECO', 'CORBATA', 'TRAJE'],
#  ['CALCETIN', 'TRAJE'],
#  ['CALZADO'],
#  ['CAMISA SP', 'CORBATA', 'TRAJE'],
#  ['CHALECO V'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['CORBATA', 'MANCUERNIL'],
#  ['CORBATA'],
#  ['BLAZER', 'PANTALON V'],
#  ['CALCETIN', 'PANUELO'],
#  ['TRAJE'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['PLAYPOLO'],
#  ['SACO SPORT'],
#  ['BLAZER'],
#  ['CORBATA'],
#  ['CAMISA V', 'PANTALON V', 'SACO SPORT'],
#  ['TRAJE'],
#  ['SMOKING'],
#  ['CALCETIN', 'CAMISA V', 'CINTURON', 'PANTALON S', 'SACO SPORT'],
#  ['CORBATA'],
#  ['TRAJE'],
#  ['CALCETIN', 'CALZADO', 'CAMISA V', 'MONO', 'TIRANTES', 'TRAJE TRIO'],
#  ['TRAJE TRIO'],
#  ['CAMISA V', 'CHAMARRA', 'PANTALON S', 'SUETER'],
#  ['CORBATA'],
#  ['JEANS'],
#  ['TRAJE', 'TRAJE TRIO'],
#  ['CINTURON'],
#  ['CAMISA V', 'TRAJE'],
#  ['CALCETIN', 'CHALECO'],
#  ['CAMISA SP'],
#  ['TRAJE'],
#  ['CORBATA'],
#  ['PANTALON S'],
#  ['TRAJE'],
#  ['PANTALON S'],
#  ['CAMISA V', 'TRAJE'],
#  ['CAMISA V'],
#  ['PANTALON S'],
#  ['PANTALON S', 'PANTALON V'],
#  ['TRAJE'],
#  ['CAMISA SP', 'CAMISA V'],
#  ['CALCETIN', 'CALZADO'],
#  ['PLAYERA'],
#  ['CAMISA V', 'SMOKING'],
#  ['PANTALON V', 'SACO SPORT'],
#  ['CHALECO'],
#  ['CHALECO', 'TRAJE'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['CAMISA V', 'PANTALON S', 'PANTALON V', 'SACO SPORT'],
#  ['CAMISA V', 'PANTALON V', 'SACO SPORT'],
#  ['CALCETIN', 'TRAJE'],
#  ['CAMISA V'],
#  ['CHAMARRA'],
#  ['PLAYERA'],
#  ['CINTURON', 'CORBATA', 'TRAJE'],
#  ['SACO SPORT'],
#  ['CALCETIN', 'CHAMARRA'],
#  ['ABRIGO', 'PANTALON V'],
#  ['TRAJE'],
#  ['TRAJE TRIO'],
#  ['CAMISA SP'],
#  ['CORBATA'],
#  ['CAMISA V'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['TRAJE'],
#  ['SACO SPORT'],
#  ['PLAYERA'],
#  ['PANTALON V'],
#  ['CINTURON'],
#  ['TRAJE TRIO'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['SACO SPORT'],
#  ['CALCETIN', 'CINTURON', 'TRAJE'],
#  ['CALZADO'],
#  ['TRAJE'],
#  ['BRAZALETE', 'CAMISA V', 'PANUELO', 'TRAJE'],
#  ['TIRANTES'],
#  ['CAMISA SP', 'PLUMAS'],
#  ['PANTALON S'],
#  ['CAMISA V', 'TRAJE'],
#  ['PANTALON S', 'SACO SPORT'],
#  ['CALCETIN'],
#  ['CORBATA'],
#  ['CALCETIN', 'CAMISA V', 'CORBATA', 'TRAJE TRIO'],
#  ['CAMISA V', 'TRAJE'],
#  ['CHALECO V', 'PANTS', 'SACO SPORT'],
#  ['TRAJE'],
#  ['CAMISA V', 'CHALECO V', 'SACO SPORT', 'TRAJE'],
#  ['SMOKING'],
#  ['TRAJE'],
#  ['CALCETIN', 'TRAJE'],
#  ['SMOKING'],
#  ['TRAJE'],
#  ['CAMISA V'],
#  ['CHAMARRA'],
#  ['PANTALON S', 'TRAJE'],
#  ['CALCETIN', 'CAMISA SP', 'CAMISA V'],
#  ['CALCETIN', 'CINTURON', 'PLAYPOLO'],
#  ['PLAYERA'],
#  ['CALZADO'],
#  ['POLOML'],
#  ['TRAJE'],
#  ['SACO SPORT'],
#  ['CAMISA V', 'PANTALON V', 'SACO SPORT'],
#  ['SMOKING', 'TRAJE TRIO'],
#  ['CINTURON'],
#  ['PLAYERA'],
#  ['CAMISA V'],
#  ['CAMISA SP'],
#  ['TRAJE'],
#  ['CAMISA SP', 'CAMISA V'],
#  ['CALCETIN', 'CAMISA V', 'CORBATA', 'TRAJE'],
#  ['PANTALON V', 'SACO SPORT'],
#  ['CAMISA V'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['TRAJE TRIO'],
#  ['SUETER'],
#  ['MANCUERNIL'],
#  ['CAMISA V'],
#  ['PANTALON S', 'PANTALON V'],
#  ['CHAMARRA'],
#  ['TRAJE'],
#  ['CAMISA V', 'SACO SPORT'],
#  ['CALCETIN', 'CAMISA V', 'PANTALON S', 'PANTALON V', 'SACO SPORT'],
#  ['PANTALON V'],
#  ['TRAJE'],
#  ['SACO SPORT'],
#  ['CAMISA V'],
#  ['CORBATA'],
#  ['CAMISA V'],
#  ['TRAJE'],
#  ['CALCETIN', 'PANTALON V', 'ROPA INT', 'SACO SPORT'],
#  ['TRAJE'],
#  ['CORBATA', 'PANUELO', 'TRAJE'],
#  ['PANTALON V', 'TRAJE'],
#  ['SACO SPORT'],
#  ['TRAJE'],
#  ['CAMISA V', 'TRAJE'],
#  ['BLAZER', 'CAMISA V', 'PANTALON S'],
#  ['TRAJE'],
#  ['CAMISA SP'],
#  ['SUETER'],
#  ['CALZADO', 'CORBATA'],
#  ['CAMISA V', 'CHAMARRA', 'PANTALON V', 'SACO SPORT'],
#  ['SACO SPORT'],
#  ['SUETER'],
#  ['CALCETIN'],
#  ['CAMISA V', 'PANTALON V', 'TRAJE TRIO'],
#  ['TRAJE'],
#  ['CHALECO'],
#  ['CALCETIN', 'PANUELO'],
#  ['CAMISA V'],
#  ['CHALECO'],
#  ['MONO', 'PANTALON V', 'SACO SPORT'],
#  ['CAMISA V', 'TRAJE'],
#  ['TRAJE TRIO'],
#  ['SACO SPORT'],
#  ['CAMISA V', 'CORBATA', 'MANCUERNIL', 'TRAJE'],
#  ['TRAJE'],
#  ['PANTALON S'],
#  ['CORBATA'],
#  ['PLAYERA'],
#  ['TRAJE'],
#  ['CAMISA V'],
#  ['SACO SPORT'],
#  ['CAMISA V', 'PANTALON V'],
#  ['CORBATA'],
#  ['MONO', 'SMOKING'],
#  ['PANTALON S', 'PANTALON V', 'PLAYERA'],
#  ['GORRA', 'PLAYERA', 'TRAJE'],
#  ['CAMISA SP', 'CORBATA', 'TRAJE'],
#  ['SMOKING'],
#  ['CAMISA V'],
#  ['CALZADO', 'CINTURON', 'GORRA', 'JEANS', 'PANTALON V', 'PLAYPOLO', 'TRAJE'],
#  ['CAMISA V'],
#  ['CAMISA V'],
#  ['MONO'],
#  ['CHAMARRA'],
#  ['CAMISA V', 'PANTALON V', 'SACO SPORT'],
#  ['PANTALON S', 'SACO SPORT', 'TRAJE'],
#  ['PANTALON V'],
#  ['SACO SPORT'],
#  ['CAMISA V', 'TRAJE'],
#  ['CALCETIN'],
#  ['TRAJE', 'TRAJE TRIO'],
#  ['CAMISA V', 'SACO SPORT'],
#  ['CAMISA V'],
#  ['CAMISA V'],
#  ['CORBATA'],
#  ['CAMISA V'],
#  ['TRAJE TRIO'],
#  ['TRAJE'],
#  ['CORBATA', 'PANUELO'],
#  ['BLAZER', 'CAMISA V'],
#  ['SACO SPORT'],
#  ['CHALECO', 'CHALECO V', 'PANUELO', 'SACO SPORT'],
#  ['CALCETIN'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['CAMISA SP', 'CAMISA V', 'SACO SPORT'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['PANTS', 'PLAYERA'],
#  ['PANTALON S'],
#  ['MONO', 'SMOKING'],
#  ['TRAJE'],
#  ['CAMISA V'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['CAMISA V', 'JEANS'],
#  ['CALCETIN', 'CORBATA', 'TRAJE'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['CALZADO', 'SACO SPORT'],
#  ['TRAJE'],
#  ['CHAMARRA'],
#  ['TRAJE'],
#  ['SACO SPORT'],
#  ['BLAZER'],
#  ['CHALECO'],
#  ['CAMISA V'],
#  ['CHAMARRA', 'ROPA INT'],
#  ['SACO SPORT', 'TRAJE'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['PANUELO'],
#  ['CAMISA V'],
#  ['TRAJE'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['CALZADO', 'CAMISA V', 'CORBATA', 'MANCUERNIL', 'TRAJE'],
#  ['CORBATA'],
#  ['CAMISA V'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['TRAJE'],
#  ['SACO SPORT'],
#  ['GABARDINA'],
#  ['MONO', 'PANUELO'],
#  ['PANUELO'],
#  ['PANTALON V', 'SACO SPORT'],
#  ['CAMISA SP', 'CAMISA V'],
#  ['TIRANTES'],
#  ['CALCETIN', 'TRAJE'],
#  ['CAMISA V', 'SACO SPORT'],
#  ['PANTALON V'],
#  ['TRAJE'],
#  ['CALZADO', 'TRAJE'],
#  ['TRAJE'],
#  ['CAMISA V', 'CINTURON', 'TRAJE'],
#  ['CHALECO'],
#  ['TRAJE', 'TRAJE TRIO'],
#  ['PANTALON S'],
#  ['SMOKING'],
#  ['PANTALON S'],
#  ['TRAJE'],
#  ['CAMISA V', 'JEANS', 'SACO SPORT'],
#  ['BLAZER'],
#  ['CAMISA V'],
#  ['CAMISA V'],
#  ['CAMISA V', 'SACO SPORT'],
#  ['CAMISA V'],
#  ['CHAMARRA'],
#  ['CALCETIN', 'CAMISA V', 'CORBATA', 'TRAJE'],
#  ['CAMISA V', 'CHALECO V', 'PANTALON V', 'SACO SPORT'],
#  ['JEANS'],
#  ['CAMISA V', 'CHAMARRA', 'TRAJE'],
#  ['CALCETIN', 'SACO SPORT'],
#  ['CORBATA'],
#  ['CAMISA V'],
#  ['CAMISA V'],
#  ['PANUELO'],
#  ['PANTALON V'],
#  ['CHAMARRA', 'JEANS'],
#  ['PLAYERA', 'PLAYPOLO'],
#  ['CHALECO'],
#  ['PANTALON V'],
#  ['CHAMARRA', 'SACO SPORT'],
#  ['MONO'],
#  ['PANTALON V'],
#  ['CHAMARRA', 'SACO SPORT'],
#  ['CHALECO'],
#  ['PLAYERA'],
#  ['CAMISA V', 'CORBATA', 'MANCUERNIL'],
#  ['CAMISA V', 'TRAJE TRIO'],
#  ['CAMISA SP', 'CAMISA V'],
#  ['CORBATA'],
#  ['CAMISA V', 'CORBATA', 'SMOKING'],
#  ['MANCUERNIL'],
#  ['CAMISA V'],
#  ['PIJAMA'],
#  ['PANUELO'],
#  ['CAMISA SP'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['PANUELO'],
#  ['CALCETIN', 'CALZADO', 'CAMISA V', 'MONO', 'TIRANTES', 'TRAJE TRIO'],
#  ['TRAJE'],
#  ['PANUELO'],
#  ['CALZADO', 'TIRANTES'],
#  ['CALCETIN'],
#  ['CAMISA SP'],
#  ['PANTALON V'],
#  ['BLAZER', 'SACO SPORT'],
#  ['PANTALON V', 'PANUELO', 'SACO SPORT'],
#  ['CAMISA V', 'JEANS'],
#  ['PLAYPOLO'],
#  ['BACKPACK'],
#  ['CHAMARRA'],
#  ['TRAJE'],
#  ['CHAMARRA'],
#  ['CAMISA V'],
#  ['BLAZER', 'CAMISA V', 'PANTALON S'],
#  ['CAMISA V', 'SMOKING'],
#  ['CAMISA V', 'MONO', 'TRAJE TRIO'],
#  ['MANCUERNIL'],
#  ['CAMISA V', 'PANTALON S'],
#  ['CAMISA V', 'TRAJE'],
#  ['PANTALON V'],
#  ['SACO SPORT'],
#  ['TRAJE'],
#  ['PLAYERA'],
#  ['CHALECO', 'CORBATA', 'PANUELO', 'TRAJE'],
#  ['PANTALON S'],
#  ['CAMISA V', 'CORBATA', 'MANCUERNIL', 'TRAJE'],
#  ['CORBATA'],
#  ['CORBATA'],
#  ['CAMISA V', 'TRAJE'],
#  ['CALCETIN'],
#  ['CALCETIN', 'CAMISA V', 'MANCUERNIL', 'TRAJE'],
#  ['CAMISA V', 'TRAJE'],
#  ['TRAJE'],
#  ['CORBATA', 'PANTALON V', 'SACO SPORT'],
#  ['CAMISA V'],
#  ['SMOKING'],
#  ['TRAJE TRIO'],
#  ['PANUELO'],
#  ['CAMISA V'],
#  ['PANTALON V'],
#  ['CINTURON', 'PANUELO'],
#  ['TRAJE'],
#  ['PANTALON S'],
#  ['CAMISA V', 'PANTALON S'],
#  ['SACO SPORT'],
#  ['CAMISA V', 'TRAJE TRIO'],
#  ['TRAJE'],
#  ['CALCETIN', 'CAMISA SP'],
#  ['PANTALON V'],
#  ['MONO'],
#  ['CHALECO', 'PLAYERA'],
#  ['CAMISA V', 'CORBATA', 'PANUELO', 'TRAJE'],
#  ['CHAMARRA'],
#  ['TRAJE'],
#  ['CHALECO', 'PANTALON V'],
#  ['CAMISA V'],
#  ['CAMISA V'],
#  ['PANTALON V'],
#  ['CORBATA'],
#  ['SUETER'],
#  ['PANUELO'],
#  ['CINTURON'],
#  ['CAMISA V', 'TRAJE'],
#  ['PANUELO'],
#  ['MONO'],
#  ['BLAZER', 'CORBATA'],
#  ['PANUELO', 'SACO SPORT'],
#  ['SUETER'],
#  ['SACO SPORT'],
#  ['CALZADO', 'SACO SPORT'],
#  ['TRAJE'],
#  ['SACO SPORT'],
#  ['TRAJE'],
#  ['CALZADO', 'CINTURON', 'CORBATA', 'TRAJE'],
#  ['PISACORBAT'],
#  ['CAMISA V'],
#  ['TRAJE'],
#  ['CAMISA V'],
#  ['CAMISA V', 'MANCUERNIL', 'PANUELO'],
#  ['CAMISA V'],
#  ['CAMISA V', 'PANUELO', 'TRAJE'],
#  ['TRAJE'],
#  ['BLAZER', 'CAMISA V', 'CORBATA'],
#  ['CORBATA'],
#  ['TRAJE'],
#  ['BRAZALETE', 'PULSERA'],
#  ['CAMISA V', 'PANTALON V', 'SACO SPORT'],
#  ['PANTALON V', 'SACO SPORT'],
#  ['CINTURON'],
#  ['CALCETIN', 'CAMISA V', 'CHALECO', 'CORBATA', 'MANCUERNIL', 'TRAJE'],
#  ['FAJAYMONO'],
#  ['CARTERA'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['CINTURON'],
#  ['CAMISA V', 'MANCUERNIL', 'TRAJE'],
#  ['PANTALON V'],
#  ['PANTALON S'],
#  ['CALCETIN', 'CALZADO'],
#  ['CAMISA V'],
#  ['CAMISA V', 'PANUELO'],
#  ['PANTALON V'],
#  ['CAMISA V'],
#  ['CAMISA V'],
#  ['CALCETIN', 'CALZADO', 'CORBATA'],
#  ['CAMISA V'],
#  ['TRAJE'],
#  ['CHALECO', 'CINTURON', 'TRAJE'],
#  ['CAMISA V', 'TRAJE'],
#  ['PLAYPOLO'],
#  ['PANTALON S'],
#  ['PISACORBAT'],
#  ['CAMISA V', 'MONO', 'PANTALON V', 'TIRANTES'],
#  ['TRAJE'],
#  ['PLAYPOLO'],
#  ['CHAMARRA'],
#  ['PANTALON S'],
#  ['BRAZALETE'],
#  ['SACO SPORT'],
#  ['CAMISA V', 'TRAJE'],
#  ['CHALECO', 'PANTALON S'],
#  ['CORBATA'],
#  ['CAMISA V'],
#  ['TRAJE TRIO'],
#  ['CAMISA V'],
#  ['CHALECO', 'TRAJE'],
#  ['MONO'],
#  ['PANTALON V', 'TRAJE'],
#  ['CALZADO'],
#  ['SACO SPORT'],
#  ['SMOKING'],
#  ['CINTURON'],
#  ['CAMISA V'],
#  ['CINTURON'],
#  ['MONO'],
#  ['CORBATA', 'SACO SPORT'],
#  ['PLAYPOLO'],
#  ['CAMISA V', 'SACO SPORT'],
#  ['MALETA'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['PANTALON S'],
#  ['PLAYERA'],
#  ['CALCETIN', 'SMOKING'],
#  ['CAMISA SP', 'CAMISA V', 'PANTALON S', 'SACO SPORT'],
#  ['CAMISA V'],
#  ['CAMISA V'],
#  ['TRAJE'],
#  ['PANTS', 'PLAYERA'],
#  ['TRAJE'],
#  ['BLAZER', 'CHALECO', 'SACO SPORT'],
#  ['SACO SPORT'],
#  ['TRAJE'],
#  ['PANTALON V'],
#  ['TRAJE'],
#  ['CALZADO'],
#  ['SACO SPORT'],
#  ['CORBATA', 'TRAJE'],
#  ['CALCETIN', 'CAMISA V'],
#  ['CAMISA V', 'CORBATA', 'MANCUERNIL', 'SUETER'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['PANTALON V'],
#  ['PULSERA'],
#  ['PISACORBAT'],
#  ['CAMISA V', 'PANTALON V', 'SACO SPORT'],
#  ['MANCUERNIL'],
#  ['TRAJE TRIO'],
#  ['CORBATA', 'PANTALON V'],
#  ['CALCETIN', 'CORBATA'],
#  ['CAMISA V', 'TRAJE'],
#  ['CALCETIN', 'CHAMARRA'],
#  ['CAMISA V'],
#  ['CAMISA V', 'PANTALON V'],
#  ['CAMISA V', 'SMOKING'],
#  ['SACO SPORT'],
#  ['MONO', 'PANUELO'],
#  ['FAJAYMONO', 'MANCUERNIL'],
#  ['MONO'],
#  ['SACO SPORT', 'SMOKING'],
#  ['CHAMARRA'],
#  ['CALZADO'],
#  ['PANUELO'],
#  ['CORBATA'],
#  ['TRAJE'],
#  ['CAMISA V', 'CORBATA', 'TRAJE'],
#  ['CORBATA', 'PANUELO', 'TRAJE'],
#  ['CAMISA V', 'PANTALON V', 'PANTS', 'SACO SPORT'],
#  ['PLAYERA', 'PLAYPOLO'],
#  ['CAMISA V', 'CORBATA', 'PANUELO', 'TRAJE'],
#  ['PANTALON S', 'SACO SPORT'],
#  ['CAMISA V', 'TRAJE'],
#  ['CAMISA V', 'TRAJE'],
#  ['PLAYERA'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['TRAJE'],
#  ['CALCETIN', 'CAMISA V', 'CINTURON', 'TRAJE'],
#  ['CHAMARRA', 'SACO SPORT'],
#  ['TRAJE'],
#  ['CAMISA SP', 'CAMISA V', 'PANTALON S'],
#  ['TRAJE'],
#  ['SACO SPORT'],
#  ['CHAMARRA', 'SACO SPORT', 'TRAJE'],
#  ['BILLETERA'],
#  ['CAMISA SP'],
#  ['CAMISA SP'],
#  ['CAMISA V'],
#  ['JEANS'],
#  ['CALCETIN'],
#  ['CAMISA SP', 'CAMISA V', 'PANTALON S', 'PANTALON V', 'SACO SPORT'],
#  ['CAMISA SP', 'CAMISA V', 'PANTALON S'],
#  ['PANTALON V'],
#  ['TRAJE'],
#  ['PLAYERA'],
#  ['CAMISA V', 'CORBATA', 'TRAJE TRIO'],
#  ['TRAJE'],
#  ['CHALECO', 'CORBATA', 'TRAJE'],
#  ['TIRANTES'],
#  ['SACO SPORT'],
#  ['BACKPACK'],
#  ['CAMISA V', 'MANCUERNIL'],
#  ['CHAMARRA'],
#  ['BLAZER', 'CAMISA V', 'CORBATA', 'JEANS', 'PANUELO', 'TRAJE'],
#  ['MANCUERNIL'],
#  ...]

# %%
import numpy as np
import matplotlib.pyplot as plt
from apyori import apriori

# %%
reglas_asociacion = apriori(resultado, min_support=0.02,min_confidence=0.20, min_lift=1,min_length=2)

resultados_asociacion=list(reglas_asociacion)

# %%
print(len(resultados_asociacion))
# Out:
# 8

# %%
# EL resultado tiene que tener más de 1 elemento, caso contrario descartar
len(resultados_asociacion[2][0])
# Out:
# 2

# %%
reg=6
print(resultados_asociacion[reg],'\n\n')

print(resultados_asociacion[reg][0],'\n')
print(resultados_asociacion[reg][1],'\n')
print(resultados_asociacion[reg][2][0][0],'\n')
# Out:
# RelationRecord(items=frozenset({'PANTALON V', 'SACO SPORT'}), support=0.026776074282012525, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PANTALON V'}), items_add=frozenset({'SACO SPORT'}), confidence=0.28181818181818186, lift=1.8997088791848618)])
#
#
# frozenset({'PANTALON V', 'SACO SPORT'})
#
# 0.026776074282012525
#
# frozenset({'PANTALON V'})

# %%
asoc=[]
for item in resultados_asociacion:
    pair = item[0]
    items= [z for z in pair ]
    print(items[0])
# Out:
# CAMISA V
# TRAJE
# CAMISA V
# CAMISA V
# CALZADO
# CAMISA SP
# CAMISA V
# MANCUERNIL
# PANTALON V
# PANUELO
# CAMISA V
# CAMISA V
# CAMISA V
# CORBATA
# PANTALON V
# CAMISA V
# PANTALON V
